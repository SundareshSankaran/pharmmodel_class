# %%
import statsmodels.api as sm

# %%
import statsmodels

# %%
from statsmodels.discrete.discrete_model import RandomForest
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from statsmodels.discrete.discrete_model import RandomForest
#
# ImportError: cannot import name 'RandomForest' from 'statsmodels.discrete.discrete_model' (/Users/sinsrn/current_projects/pharmmodel_class/build/pharmmod/lib/python3.13/site-packages/statsmodels/discrete/discrete_model.py)

# %%
help(sm)
# Out:
# Help on module statsmodels.discrete.discrete_model in statsmodels.discrete:
#
# NAME
#     statsmodels.discrete.discrete_model - Limited dependent variable and qualitative variables.
#
# DESCRIPTION
#     Includes binary outcomes, count data, (ordered) ordinal data and limited
#     dependent variables.
#
#     General References
#     --------------------
#
#     A.C. Cameron and P.K. Trivedi.  `Regression Analysis of Count Data`.
#         Cambridge, 1998
#
#     G.S. Madalla. `Limited-Dependent and Qualitative Variables in Econometrics`.
#         Cambridge, 1983.
#
#     W. Greene. `Econometric Analysis`. Prentice Hall, 5th. edition. 2003.
#
# CLASSES
#     BinaryModel(DiscreteModel)
#         Logit
#         Probit
#     DiscreteModel(statsmodels.base.model.LikelihoodModel)
#         CountModel
#             GeneralizedPoisson
#             NegativeBinomial
#             NegativeBinomialP
#             Poisson
#     MultinomialModel(BinaryModel)
#         MNLogit
#
# ...
