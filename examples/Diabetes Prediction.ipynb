# %%
from pharmmod import PharmMod

# %%
pm = PharmMod(path="https://raw.githubusercontent.com/sassoftware/sas-viya-workbench-demos/refs/heads/main/health-life-sciences/diabetes-prediction-through-synthetic-data/data/diabetes_prediction_dataset.csv",
              target="Outcome")

# %%
pm.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
pm.visualize()

# %%
pm.visualize_category()
# Out:
# Column Pregnancies has more than 10 unique values. Please select a different column.
# Column BloodPressure has more than 10 unique values. Please select a different column.
# Column Insulin has more than 10 unique values. Please select a different column.
# Column DiabetesPedigreeFunction has more than 10 unique values. Please select a different column.

# %%
pm.partition()

# %%
pm.forest_classifier()
# Out:
# Training F1 Score: 100.0
# Validation F1 Score: 56.54
# Test F1 Score: 58.82

# %%
pm.forest_classifier(col=["Pregnancies","Glucose","BloodPressure","BMI","Age"])
# Out:
# Training F1 Score: 100.0
# Validation F1 Score: 58.29
# Test F1 Score: 64.0

# %%
pm.forest_classifier(col=["Insulin","Glucose","BloodPressure","BMI","Age"])
# Out:
# Training F1 Score: 100.0
# Validation F1 Score: 57.29
# Test F1 Score: 58.33

# %%
pm.models_run
# Out:
# [{'model_type': 'Random Forest Classifier',
#   'model': RandomForestClassifier(random_state=42),
#   'Training F1': 100.0,
#   'Validation F1': 56.54,
#   'Test F1': 58.82,
#   'target': 'Outcome',
#   'features': Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#          'BMI', 'DiabetesPedigreeFunction', 'Age'],
#         dtype='object')},
#  {'model_type': 'Random Forest Classifier',
#   'model': RandomForestClassifier(random_state=42),
#   'Training F1': 100.0,
#   'Validation F1': 58.29,
#   'Test F1': 64.0,
#   'target': 'Outcome',
#   'features': ['Pregnancies', 'Glucose', 'BloodPressure', 'BMI', 'Age']},
#  {'model_type': 'Random Forest Classifier',
#   'model': RandomForestClassifier(random_state=42),
#   'Training F1': 100.0,
#   'Validation F1': 57.29,
#   'Test F1': 58.33,
#   'target': 'Outcome',
#   'features': ['Insulin', 'Glucose', 'BloodPressure', 'BMI', 'Age']}]

# %%
pm.logistic_regression()
# Out:
# Training F1 Score: 69.46
# Validation F1 Score: 54.35
# Test F1 Score: 64.0

# %%
pm.xgboost_classifier()
# Out:
# Training F1 Score: 100.0
# Validation F1 Score: 58.82
# Test F1 Score: 59.57

# %%
pm.decision_tree_classifier()
# Out:
# Training F1 Score: 100.0
# Validation F1 Score: 55.24
# Test F1 Score: 66.67

# %%
pm.name = "Diabetes PIMA Indians"
pm.describe()
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 139294.23it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Render JSON:   0%|          | 0/1 [00:00<?, ?it/s]
#     count        mean         std     min       25%       50%        75%  \
# id
# 0   768.0    3.845052    3.369578   0.000   1.00000    3.0000    6.00000
# 1   768.0  120.894531   31.972618   0.000  99.00000  117.0000  140.25000
# 2   768.0   69.105469   19.355807   0.000  62.00000   72.0000   80.00000
# 3   768.0   20.536458   15.952218   0.000   0.00000   23.0000   32.00000
# 4   768.0   79.799479  115.244002   0.000   0.00000   30.5000  127.25000
# 5   768.0   31.992578    7.884160   0.000  27.30000   32.0000   36.60000
# 6   768.0    0.471876    0.331329   0.078   0.24375    0.3725    0.62625
# 7   768.0   33.240885   11.760232  21.000  24.00000   29.0000   41.00000
# 8   768.0    0.348958    0.476951   0.000   0.00000    0.0000    1.00000
#
#        max               column_name
# id
# 0    17.00               Pregnancies
# 1   199.00                   Glucose
# 2   122.00             BloodPressure
# 3    99.00             SkinThickness
# 4   846.00                   Insulin
# 5    67.10                       BMI
# 6     2.42  DiabetesPedigreeFunction
# 7    81.00                       Age
# 8     1.00                   Outcome

# %%
pm.dataframes[0]["Outcome"].nunique()
# Out:
# 2
